# %%
import csv
import pandas as pd

# %%
fileName=r"F:\Wexin\WeChat Files\wxid_vifv96c9c98r22\FileStorage\File\2023-09\img_caption(1).csv"
data=pd.read_csv(fileName)

# %%
#百度通用翻译API,不包含词典、tts语音合成等资源，如有相关需求请联系translate_api@baidu.com
# coding=utf-8

import http.client
import hashlib
import urllib
import random
import json

def trans_en_ch(txt):
    appid = '20230718001749154'  # 填写你的appid
    secretKey = 'BhB7cnNkMzwhEGCmSlus'  # 填写你的密钥

    httpClient = None
    myurl = '/api/trans/vip/translate'

    fromLang = 'zh'   #原文语种
    toLang = 'en'   #译文语种
    salt = random.randint(32768, 65536)
    q= txt
    sign = appid + q + str(salt) + secretKey
    sign = hashlib.md5(sign.encode()).hexdigest()
    myurl = myurl + '?appid=' + appid + '&q=' + urllib.parse.quote(q) + '&from=' + fromLang + '&to=' + toLang + '&salt=' + str(
    salt) + '&sign=' + sign

    try:
        httpClient = http.client.HTTPConnection('api.fanyi.baidu.com')
        httpClient.request('GET', myurl)

        # response是HTTPResponse对象
        response = httpClient.getresponse()
        result_all = response.read().decode("utf-8")
        result = json.loads(result_all)
        # print('翻译：：')
        return result['trans_result'][0]['dst']
        # print (result)

    except Exception as e:
        print (e)
    finally:
        if httpClient:
            httpClient.close()

# %%
en = trans_en_ch('我是')
print(en)
# Out:
# I am

# %%
print(len(data['label']))
# Out:
# 11184

# %%
# clean_num = []
clean_title1 = []
clean_image1 = []
clean_text_en1 = []
clean_text_ch1 = []
clean_title_en1 = []
for i,summary in enumerate(data['text']):
    if i < 4901:
        continue

    # num = data['num'][i]
    img = data['image'][i]
    ti = data['title'][i]
    en_text = trans_en_ch(str(summary))
    en_title = trans_en_ch(str(ti))
    clean_title_en1.append(en_title)
    # clean_num.append(num)
    clean_title1.append(ti)
    clean_image1.append(img)
    clean_text_en1.append(en_text)
    clean_text_ch1.append(str(data['text'][i]))
# Out:
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# 'trans_result'
# ...

# %%
clean_title2 = clean_title1 + clean_title
clean_text_ch2 = clean_text_ch1 + clean_text_ch
clean_image2 = clean_image1 + clean_image
clean_title_en2 = clean_title_en1 + clean_title_en
clean_text_en2 = clean_text_en1 + clean_text_en

# %%
data = pd.DataFrame({'title':clean_title2,'text':clean_text_ch2,'image':clean_image2,'en_title':clean_title_en2,'en_text':clean_text_en2,'caption':data['caption'],'label':data['label']}) #,'cate':clean_cate
data.to_csv('F:\\baidu_competition\\queries_dataset_merge\\English_train_data1






.csv', index=False)

# %%
fileName=r"F:\SPIDER_DATA\English_real_data.csv"
data1=pd.read_csv(fileName)
clean_title_en = data1['en_title']
len(clean_text_en)
# Out:
# 15828

# %%
data = pd.DataFrame({'num':clean_num,'title':clean_title,'text':clean_text,'en_title':clean_title_en,'en_text':clean_text_en,'image':clean_image}) #,'cate':clean_cate
data.to_csv('English_fake_all_data.csv', index=False)

# %%
with open('C:\\Users\\ZQ\\Desktop\\weibo_BLIP_dataset_train_ch1.txt',"w",encoding = 'utf-8') as file:
    for post,t,c,img,lab,t_m,c_m in zip(post_id, all_txt, all_ch_cap, all_img, all_label, all_txt_mid, all_cap_mid):
        file.write(post + '\t' + t + '\t' + c + '\t' + img + '\t' + lab + '\t' + t_m + '\t' + c_m + "\n")

# %%
cap =  all_cap[1765]

# %%
y = trans_en_ch(cap)
print(y)
# Out:
# 抱着婴儿的女人。63 5深圳微微博om1388034000
